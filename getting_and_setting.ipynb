# %% [markdown]
# <a href="https://colab.research.google.com/github/edercarmonaa/IntroToOpenCV/blob/main/getting_and_setting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
from matplotlib import pyplot as plt
import cv2

image = cv2.imread("TyrannosaurusRex.jpg")
print("Original")
plt.axis("off")
plt.imshow(image)
plt.show()
# Out:
# Original

# %%
(b, g, r) = image[0, 0]
print("Pixel at (0, 0) - Red: {}, Green: {}, Blue: {}".format(r,g, b))
image[0, 0] = (0, 0, 255)
(b, g, r) = image[0, 0]
print("Pixel at (0, 0) - Red: {}, Green: {}, Blue: {}".format(r,g, b))
# Out:
# Pixel at (0, 0) - Red: 255, Green: 255, Blue: 255
# Pixel at (0, 0) - Red: 255, Green: 0, Blue: 0

# %%
corner = image[0:100, 0:100]
plt.axis("off")
plt.imshow(corner)
plt.show()

# %%
image[0:100, 0:100] = (0, 255, 0)
plt.axis("off")
plt.imshow(image)
plt.show()
